# %%
import numpy as np
from utils import *
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 3
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
m = L96_XY()

# %%
# %%time 
m.warmup(20000)
# Out:
# CPU times: user 1.62 s, sys: 66.6 ms, total: 1.68 s
# Wall time: 1.61 s

# %%
# %%time
ds_train = m.run(50000, 20, collect_coupling=True)
# Out:
# CPU times: user 1min 17s, sys: 929 ms, total: 1min 18s
# Wall time: 1min 18s

# %%
# %%time
ds_val = m.run(5000, 20, collect_coupling=True)
# Out:
# CPU times: user 7.94 s, sys: 163 ms, total: 8.1 s
# Wall time: 7.93 s

# %%
# %%time
ds_test = m.run(5000, 20, collect_coupling=True)
# Out:
# CPU times: user 7.92 s, sys: 144 ms, total: 8.07 s
# Wall time: 7.91 s

# %%
ds_train.to_netcdf('datasets/train.nc')

# %%
ds_val.to_netcdf('datasets/val.nc')

# %%
ds_test.to_netcdf('datasets/test.nc')

# %%
X = ds_test.X.values.ravel()

# %%
Xcouple = ds_test.Xcouple.values.ravel()

# %%
plt.plot(X[:1024],Xcouple[:1024], '.')
plt.xlabel('X[k]')
plt.ylabel('Coupling[k]')
plt.title('Subgrid tendency')
# Out:
# Text(0.5, 1.0, 'Subgrid tendency')
